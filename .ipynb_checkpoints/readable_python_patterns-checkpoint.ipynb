# %%
# 1. Variable Names 
# e.g variable_names = 

student_age = 13
student_name = "Mary John"

print(f'Student Name: {student_name}, Student age is: {student_age} ')
# Out:
# Student Name: Mary John, Student age is: 13
