# %%
from scapy.all import *

pkt = IP()

pkt.canvas_dump()

print('---------------------------------------')
print('')


packets = rdpcap('/home/sci-laptop/PyCode/scapy/sonosonePOWER_1.pcap')
packets.summary()  

ans, unans = traceroute('www.secdev.org', maxttl=15)
pkt.canvas_dump()
ans.world_trace()
# Out:
# /home/sci-laptop/anaconda3/lib/python3.9/site-packages/scapy/layers/ipsec.py:471: CryptographyDeprecationWarning: Blowfish has been deprecated
#   cipher=algorithms.Blowfish,
# /home/sci-laptop/anaconda3/lib/python3.9/site-packages/scapy/layers/ipsec.py:485: CryptographyDeprecationWarning: CAST5 has been deprecated
#   cipher=algorithms.CAST5,
# ---------------------------------------
#
# 802.3 48:a6:b8:f9:1b:88 > ff:ff:ff:ff:ff:ff / LLC / Raw / Padding
# Ether / IP / UDP 0.0.0.0:bootpc > 255.255.255.255:bootps / BOOTP / DHCP
# Ether / IP / UDP 192.168.137.1:bootps > 192.168.137.120:bootpc / BOOTP / DHCP
# Ether / IP / UDP 0.0.0.0:bootpc > 255.255.255.255:bootps / BOOTP / DHCP
# Ether / IP / UDP 192.168.137.1:bootps > 192.168.137.120:bootpc / BOOTP / DHCP
# Ether / IPv6 / UDP / DNS Ans "[b'VERSION=1', b'CPath=/spotifyzc']"
# Ether / fe80::4aa6:b8ff:fef9:1b88 > ff02::16 (0) / IPv6ExtHdrHopByHop / ICMPv6MLReport2
# Ether / 192.168.137.120 > 224.0.0.22 igmp / Raw / Padding
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / ARP who has 192.168.137.1 says 192.168.137.120 / Padding
# Ether / ARP is at 3c:18:a0:45:da:85 says 192.168.137.1
# Ether / IP / UDP / DNS Qry "b'service-catalog.ws.sonos.com.'"
# Ether / ARP who has 192.168.137.120 says 192.168.137.120 / Padding
# Ether / IP / UDP / DNS Ans "3.222.57.75"
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https S
# Ether / IP / UDP / DNS Ans "b'Sonos-48A6B8F91B88.local.'"
# Ether / IPv6 / UDP / DNS Ans "b'Sonos-48A6B8F91B88.local.'"
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 SA
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https PA / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 PA / Raw
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / UDP / DNS Qry "b'_sonos._tcp.local.'"
# Ether / IPv6 / UDP / DNS Qry "b'_sonos._tcp.local.'"
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https PA / Raw
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https PA / Raw
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https PA / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34049 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34049 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34049 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34049 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 PA / Raw
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https PA / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 A / Raw
# Ether / IP / TCP 3.222.57.75:https > 192.168.137.120:38644 PA / Raw
# Ether / fe80::4aa6:b8ff:fef9:1b88 > ff02::16 (0) / IPv6ExtHdrHopByHop / ICMPv6MLReport2
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https A
# Ether / IP / TCP 192.168.137.120:38644 > 3.222.57.75:https RA
# Ether / 192.168.137.120 > 224.0.0.22 igmp / Raw
# Ether / IP / UDP 192.168.137.120:43975 > 239.255.255.250:1902 / Raw
# Ether / IP / UDP / DNS Qry "b'0.sonostime.pool.ntp.org.'"
# Ether / IP / UDP / DNS Qry "b'0.sonostime.pool.ntp.org.'"
# Ether / IP / UDP / DNS Ans "47.190.36.235"
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Qry "b'1.sonostime.pool.ntp.org.'"
# Ether / IP / UDP / DNS Qry "b'1.sonostime.pool.ntp.org.'"
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP / DNS Ans "178.62.18.76"
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Qry "b'2.sonostime.pool.ntp.org.'"
# Ether / IP / UDP / DNS Qry "b'2.sonostime.pool.ntp.org.'"
# Ether / IP / UDP / DNS Qry "b'sonos48A6B8F91B88._spotify-connect._tcp.local.'"
# Ether / IPv6 / UDP / DNS Qry "b'sonos48A6B8F91B88._spotify-connect._tcp.local.'"
# Ether / IP / UDP / DNS Ans "38.229.62.9"
# Ether / IP / UDP / DNS Ans "2604:a880:800:a1::ec9:5001"
# Ether / IP / UDP / DNS Qry "b'3.sonostime.pool.ntp.org.'"
# Ether / IP / UDP / DNS Qry "b'3.sonostime.pool.ntp.org.'"
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans "50.18.44.198"
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP / DNS Qry "b'sonos48A6B8F91B88._spotify-connect._tcp.local.'"
# Ether / IPv6 / UDP / DNS Qry "b'sonos48A6B8F91B88._spotify-connect._tcp.local.'"
# Ether / 192.168.137.120 > 224.0.0.22 igmp / Raw / Padding
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / DNS Qry "b'sonos48A6B8F91B88._spotify-connect._tcp.local.'"
# Ether / IPv6 / UDP / DNS Qry "b'sonos48A6B8F91B88._spotify-connect._tcp.local.'"
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / DNS Ans "b'Sonos-48A6B8F91B88.local.'"
# Ether / IPv6 / UDP / DNS Ans "b'Sonos-48A6B8F91B88.local.'"
# Ether / IPv6 / ICMPv6ND_RS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address 48:a6:b8:f9:1b:88
# Ether / IPv6 / ICMPv6ND_RS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address 48:a6:b8:f9:1b:88
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / DNS Qry "b'_sonos._tcp.local.'"
# Ether / IPv6 / UDP / DNS Qry "b'_sonos._tcp.local.'"
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / DNS Ans "[b'VERSION=1', b'CPath=/spotifyzc']"
# Ether / IPv6 / UDP / DNS Ans "[b'VERSION=1', b'CPath=/spotifyzc']"
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / DNS Ans "[b'VERSION=1', b'CPath=/spotifyzc']"
# Ether / IPv6 / UDP / DNS Ans "[b'VERSION=1', b'CPath=/spotifyzc']"
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP / DNS Ans "b'Sonos-48A6B8F91B88.local.'"
# Ether / IPv6 / UDP / DNS Ans "b'Sonos-48A6B8F91B88.local.'"
# Ether / IP / TCP 192.168.137.1:50979 > 192.168.137.120:1400 S
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50979 SA
# Ether / IP / TCP 192.168.137.1:50979 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50979 > 192.168.137.120:1400 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50979 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50979 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50979 A / Raw
# Ether / IP / TCP 192.168.137.1:50979 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50979 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50979 A / Raw
# Ether / IP / TCP 192.168.137.1:50979 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50979 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50979 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50979 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50979 FPA / Raw
# Ether / IP / TCP 192.168.137.1:50979 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50979 > 192.168.137.120:1400 FA
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50979 A / Padding
# Ether / IP / TCP 192.168.137.1:50980 > 192.168.137.120:1400 S
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50980 SA
# Ether / IP / TCP 192.168.137.1:50980 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50980 > 192.168.137.120:1400 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50980 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50980 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50980 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50980 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50980 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50980 A / Raw
# Ether / IP / TCP 192.168.137.1:50980 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50980 A / Raw
# Ether / IP / TCP 192.168.137.1:50980 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50980 FPA / Raw
# Ether / IP / TCP 192.168.137.1:50980 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50980 > 192.168.137.120:1400 FA
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50980 A / Padding
# Ether / IP / TCP 192.168.137.1:50981 > 192.168.137.120:1400 S
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50981 SA
# Ether / IP / TCP 192.168.137.1:50981 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50981 > 192.168.137.120:1400 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50981 A / Padding
# Ether / IP / TCP 192.168.137.1:50982 > 192.168.137.120:1400 S
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50982 SA
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50981 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50981 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50981 A / Raw
# Ether / IP / TCP 192.168.137.1:50982 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50981 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50982 > 192.168.137.120:1400 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50981 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50981 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50981 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50981 FPA / Raw
# Ether / IP / TCP 192.168.137.1:50981 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50981 > 192.168.137.120:1400 FA
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50982 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50981 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50982 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50982 FPA / Raw
# Ether / IP / TCP 192.168.137.1:50982 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50982 > 192.168.137.120:1400 FA
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50982 A / Padding
# Ether / IP / TCP 192.168.137.1:50983 > 192.168.137.120:1400 S
# Ether / IP / TCP 192.168.137.1:50984 > 192.168.137.120:1400 S
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 SA
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50984 SA
# Ether / IP / TCP 192.168.137.1:50983 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50984 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50984 > 192.168.137.120:1400 PA / Raw
# Ether / IP / TCP 192.168.137.1:50983 > 192.168.137.120:1400 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50984 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50984 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50984 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50984 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 A / Raw
# Ether / IP / TCP 192.168.137.1:50983 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50984 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50984 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50984 FPA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 A / Raw
# Ether / IP / TCP 192.168.137.1:50983 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50984 > 192.168.137.120:1400 FA
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 FPA / Raw
# Ether / IP / TCP 192.168.137.1:50983 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50983 > 192.168.137.120:1400 FA
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50984 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50983 A / Padding
# Ether / IP / TCP 192.168.137.1:50985 > 192.168.137.120:1400 S
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50985 SA
# Ether / IP / TCP 192.168.137.1:50985 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50985 > 192.168.137.120:1400 PA / Raw
# Ether / IP / TCP 192.168.137.1:50985 > 192.168.137.120:1400 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50985 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50985 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50985 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50985 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50985 FPA / Raw
# Ether / IP / TCP 192.168.137.1:50985 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50985 > 192.168.137.120:1400 FA
# Ether / IP / TCP 192.168.137.1:50986 > 192.168.137.120:1400 S
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50985 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 SA
# Ether / IP / TCP 192.168.137.1:50986 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50986 > 192.168.137.120:1400 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.1:50986 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 PA / Raw
# Ether / IP / TCP 192.168.137.1:50986 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.1:50986 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.1:50986 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Raw
# Ether / IP / TCP 192.168.137.1:50986 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 FPA / Raw
# Ether / IP / TCP 192.168.137.1:50986 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50986 > 192.168.137.120:1400 FA
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50986 A / Padding
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 S
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 SA
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Padding
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 PA / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 A
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Raw
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 FPA / Raw
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 A
# Ether / IP / TCP 192.168.137.1:50987 > 192.168.137.120:1400 FA
# Ether / IP / TCP 192.168.137.120:1400 > 192.168.137.1:50987 A / Padding
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP / DNS Qry "b'_sonos._tcp.local.'"
# Ether / IPv6 / UDP / DNS Qry "b'_sonos._tcp.local.'"
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP / DNS Ans "[b'VERSION=1', b'CPath=/spotifyzc']"
# Ether / IPv6 / UDP / DNS Ans "[b'VERSION=1', b'CPath=/spotifyzc']"
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:52500 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:52500 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / DNS Qry "b'feature-config.sslauth.sonos.com.'"
# Ether / IP / UDP / DNS Ans "b'feature-config.sslauth.sonos.com-v1.edgekey.net.'"
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https S
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 SA
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https A
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 A
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 A / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 PA / Raw
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https A
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https A
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https A
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https A / Raw
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 A
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 A
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 A
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 A
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 A / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 PA / Raw
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https A
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 A
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37788 FA
# Ether / IP / TCP 192.168.137.120:37788 > 104.105.42.188:https RA
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / DNS Ans "[b'VERSION=1', b'CPath=/spotifyzc']"
# Ether / IPv6 / UDP / DNS Ans "[b'VERSION=1', b'CPath=/spotifyzc']"
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP 192.168.137.120:43975 > 239.255.255.250:1902 / Raw
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IPv6 / ICMPv6ND_RS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address 48:a6:b8:f9:1b:88
# Ether / IPv6 / ICMPv6ND_RS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address 48:a6:b8:f9:1b:88
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP / NTP v??, ??
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP / DNS Qry "b'_sonos._tcp.local.'"
# Ether / IPv6 / UDP / DNS Qry "b'_sonos._tcp.local.'"
# Ether / IP / UDP / DNS Ans "b'Sonos-48A6B8F91B88._sonos._tcp.local.'"
# Ether / IPv6 / UDP / DNS Ans "b'Sonos-48A6B8F91B88._sonos._tcp.local.'"
# Ether / IP / UDP / DNS Qry "b'lechmere-v1.sslauth.sonos.com.'"
# Ether / IP / UDP / DNS Ans "b'lechmere-v1.sslauth.sonos.com-v1.edgekey.net.'"
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https S
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 SA
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https A
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 A
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 A / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 PA / Raw
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https A
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https A
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https A
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https A / Raw
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 A
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 A
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 A
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 A
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 A / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 PA / Raw
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https A
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 A
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 PA / Raw
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https FA
# Ether / IP / UDP / DNS Qry "b'conn-i-02a7c8ab2b83fe83e-us-east-1.lechmere.prod.ws.sonos.com.'"
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 PA / Raw
# Ether / IP / TCP 104.105.42.188:https > 192.168.137.120:37790 FA
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https R / Padding
# Ether / IP / TCP 192.168.137.120:37790 > 104.105.42.188:https R / Padding
# Ether / IP / UDP / DNS Ans "b'ec2-54-160-155-191.compute-1.amazonaws.com.'"
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https S
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 SA
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https A
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https PA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 A
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 A / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 A / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 PA / Raw
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https A
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https A
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https A
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https A / Raw
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https PA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 A
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https PA / Raw
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https PA / Raw
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https PA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 A
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 A
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 A
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 A / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 PA / Raw
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https A
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https PA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 PA / Raw
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https PA / Raw
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https PA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 A
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 PA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 PA / Raw
# Ether / IP / TCP 192.168.137.120:56668 > 54.160.155.191:https A
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IPv6 / ICMPv6ND_RS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address 48:a6:b8:f9:1b:88
# Ether / IPv6 / ICMPv6ND_RS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address 48:a6:b8:f9:1b:88
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP / DNS Qry "b'_sonos._tcp.local.'"
# Ether / IPv6 / UDP / DNS Qry "b'_sonos._tcp.local.'"
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP / DNS Qry "b'msmetrics.ws.sonos.com.'"
# Ether / IP / UDP / DNS Ans "34.234.7.212"
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https S
# Ether / IP / TCP 34.234.7.212:https > 192.168.137.120:42236 SA
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https A
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https PA / Raw
# Ether / IP / TCP 34.234.7.212:https > 192.168.137.120:42236 A
# Ether / IP / TCP 34.234.7.212:https > 192.168.137.120:42236 A / Raw
# Ether / IP / TCP 34.234.7.212:https > 192.168.137.120:42236 A / Raw
# Ether / IP / TCP 34.234.7.212:https > 192.168.137.120:42236 PA / Raw
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https A
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https A
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https A
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https PA / Raw
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https PA / Raw
# Ether / IP / TCP 34.234.7.212:https > 192.168.137.120:42236 A
# Ether / IP / TCP 34.234.7.212:https > 192.168.137.120:42236 PA / Raw
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https A
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https PA / Raw
# Ether / IP / TCP 34.234.7.212:https > 192.168.137.120:42236 PA / Raw
# Ether / IP / TCP 34.234.7.212:https > 192.168.137.120:42236 PA / Raw
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https PA / Raw
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https RA
# Ether / IP / TCP 34.234.7.212:https > 192.168.137.120:42236 FA
# Ether / IP / TCP 192.168.137.120:42236 > 34.234.7.212:https R / Padding
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IPv6 / ICMPv6ND_RS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address 48:a6:b8:f9:1b:88
# Ether / IPv6 / ICMPv6ND_RS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address 48:a6:b8:f9:1b:88
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:53771 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 239.255.255.250:1900 / Raw
# Ether / IP / UDP 192.168.137.120:34548 > 255.255.255.255:1900 / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 PA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 PA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 FA
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 FA
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 FPA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 FPA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 FPA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 FPA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 FPA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 FPA / Raw
# Ether / IP / TCP 54.160.155.191:https > 192.168.137.120:56668 FPA / Raw
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_33437/587817723.py in <module>
#      12 packets.summary()
#      13
# ---> 14 ans, unans = traceroute('www.secdev.org', maxttl=15)
#      15 pkt.canvas_dump()
#      16 ans.world_trace()
#
# ~/anaconda3/lib/python3.9/site-packages/scapy/layers/inet.py in traceroute(target, dport, minttl, maxttl, sport, l4, filter, timeout, verbose, **kargs)
#    1760         filter = "(icmp and (icmp[0]=3 or icmp[0]=4 or icmp[0]=5 or icmp[0]=11 or icmp[0]=12)) or (tcp and (tcp[13] & 0x16 > 0x10))"  # noqa: E501
#    1761     if l4 is None:
# -> 1762         a, b = sr(IP(dst=target, id=RandShort(), ttl=(minttl, maxttl)) / TCP(seq=RandInt(), sport=sport, dport=dport),  # noqa: E501
#    1763                   timeout=timeout, filter=filter, verbose=verbose, **kargs)
#    1764     else:
#
# ~/anaconda3/lib/python3.9/site-packages/scapy/sendrecv.py in sr(x, promisc, filter, iface, nofilter, *args, **kargs)
#     607     Send and receive packets at layer 3
#     608     """
# --> 609     s = conf.L3socket(promisc=promisc, filter=filter,
#     610                       iface=iface, nofilter=nofilter)
#     611     result = sndrcv(s, x, *args, **kargs)
#
# ~/anaconda3/lib/python3.9/site-packages/scapy/arch/linux.py in __init__(self, iface, type, promisc, filter, nofilter, monitor)
#     484                 "The 'monitor' argument has no effect on native linux sockets."
#     485             )
# --> 486         self.ins = socket.socket(
#     487             socket.AF_PACKET, socket.SOCK_RAW, socket.htons(type))
#     488         self.ins.setsockopt(socket.SOL_SOCKET, socket.SO_RCVBUF, 0)
#
# ~/anaconda3/lib/python3.9/socket.py in __init__(self, family, type, proto, fileno)
#     230             if proto == -1:
#     231                 proto = 0
# --> 232         _socket.socket.__init__(self, family, type, proto, fileno)
#     233         self._io_refs = 0
#     234         self._closed = False
#
# PermissionError: [Errno 1] Operation not permitted
