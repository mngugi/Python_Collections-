# %%
import numpy as np

from matplotlib import cm
from mpl_toolkits.mplot3d.axes3d import get_test_data

# Example usage
X, Y, Z = get_test_data(0.05)
print("Data shapes:", X.shape, Y.shape, Z.shape)
# Out:
# Data shapes: (120, 120) (120, 120) (120, 120)

# %%
import numpy as np
from matplotlib import cm
from mpl_toolkits.mplot3d.axes3d import get_test_data
import matplotlib.pyplot as plt

# Twice as wide as it is tall
fig = plt.figure(figsize=plt.figaspect(0.5))

# ---- First subplot
# Note that the declaration "projection='3d'" is required for 3D plots
ax = fig.add_subplot(1, 2, 1, projection='3d')

# Generate the grid
X = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)
X, Y = np.meshgrid(X, Y)

# Generate the surface data
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.GnBu, linewidth=0, antialiased=False)
ax.set_zlim3d(-1.01, 1.01)

# Add a color bar
fig.colorbar(surf, shrink=0.5, aspect=10)

# ---- Second subplot
ax = fig.add_subplot(1, 2, 2, projection='3d')

# Generate test data for the wireframe
X, Y, Z = get_test_data(0.05)
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

# Save the output to a file
outfile = '3dGraph.png'
plt.savefig(outfile, dpi=200)
print(f'Image saved to {outfile}')

# Show the plot
plt.show()
# Out:
# Image saved to 3dGraph.png

# %%
import pandas as pd 
import seaborn as sns  
import numpy as np 
import matplotlib.pyplot as plt

x = np.linspace(1, 7, 50) 
y = 3 + 2*x + 1.5*np.random.randn(len(x)) 
df = pd.DataFrame({'xData':x, 'yData':y}) 
sns.regplot('xData', 'yData')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 9
#       7 y = 3 + 2*x + 1.5*np.random.randn(len(x))
#       8 df = pd.DataFrame({'xData':x, 'yData':y})
# ----> 9 sns.regplot('xData', 'yData', data=df)
#      10 plt.show()
#
# TypeError: regplot() got multiple values for argument 'data'
