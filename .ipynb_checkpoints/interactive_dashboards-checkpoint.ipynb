# %%
import matplotlib.pyplot as plt
from ipywidgets import interact
import numpy as np

# Data
x = np.linspace(0, 10, 200)

def plot_wave(freq=1.0, amp=1.0):
    y = amp * np.sin(freq * x)
    plt.figure(figsize=(6,4))
    plt.plot(x, y)
    plt.title(f"Frequency = {freq}, Amplitude = {amp}")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.grid(True)
    plt.show()

interact(plot_wave, freq=(0.1, 10, 0.1), amp=(0.1, 5, 0.1))
# Out:
# <function __main__.plot_wave(freq=1.0, amp=1.0)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button

# Create base data
x = np.linspace(0, 10, 1000)
a0 = 1
f0 = 1
y = a0 * np.sin(2 * np.pi * f0 * x)

# Create figure and axis
fig, ax = plt.subplots()
plt.subplots_adjust(bottom=0.25)
l, = plt.plot(x, y, lw=2)

# Add sliders
axcolor = 'lightgoldenrodyellow'
axfreq = plt.axes([0.25, 0.1, 0.65, 0.03], facecolor=axcolor)
axamp = plt.axes([0.25, 0.15, 0.65, 0.03], facecolor=axcolor)

sfreq = Slider(axfreq, 'Freq', 0.1, 5.0, valinit=f0)
samp = Slider(axamp, 'Amp', 0.1, 2.0, valinit=a0)

# Update function
def update(val):
    amp = samp.val
    freq = sfreq.val
    l.set_ydata(amp * np.sin(2 * np.pi * freq * x))
    fig.canvas.draw_idle()

sfreq.on_changed(update)
samp.on_changed(update)

# Reset button
resetax = plt.axes([0.8, 0.025, 0.1, 0.04])
button = Button(resetax, 'Reset', color=axcolor, hovercolor='0.975')

def reset(event):
    sfreq.reset()
    samp.reset()
button.on_clicked(reset)

plt.show()
