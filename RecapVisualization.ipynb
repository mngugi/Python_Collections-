# %%
# bargraph
import altair as alt
import pandas as pd

source = pd.DataFrame({
    'a': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'],
    'b': [28, 55, 43, 91, 81, 53, 19, 87, 52]
})

alt.Chart(source).mark_bar().encode(
    x='a',
    y='b'
)
# Out:
# /home/x38fed/.local/lib/python3.11/site-packages/altair/utils/core.py:410: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
# linegraph
import altair as alt
import pandas as pd


source2 = pd.DataFrame ({ 
    'j': ['Lions', 'Elephants', 'Giraffs', 'Rhino', 'Buffalo'],
    'i': [2000,10000,5600, 1500, 11000]
    
})

alt.Chart(source2).mark_line().encode( x = 'j', y = 'i')
# Out:
# /home/x38fed/.local/lib/python3.11/site-packages/altair/utils/core.py:410: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data

source = data.movies.url

alt.Chart(source).mark_bar().encode(
    alt.X("IMDB_Rating:Q", bin=True),
    y='count()',
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data

# Data generators for the background
sphere = alt.sphere()
graticule = alt.graticule()

# Source of land data
source = alt.topo_feature(data.world_110m.url, 'countries')

# Layering and configuring the components
alt.layer(
    alt.Chart(sphere).mark_geoshape(fill='skyblue'),
    alt.Chart(graticule).mark_geoshape(stroke='ivory', strokeWidth=0.5),
    alt.Chart(source).mark_geoshape(fill='green', stroke='black')
).project(
    'naturalEarth1'
).properties(width=600, height=400).configure_view(stroke=None)
# Out:
# alt.LayerChart(...)

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
fifa_player = "/home/x38fed/Documents/GitHub/Python_Programming-/players_15.csv"

fifa_data = pd.read_csv(fifa_player )

fifa_data.head()

plt.figure(figsize=(16,6))
sns.lineplot(data=fifa_data)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sportify_path = "/home/x38fed/Documents/GitHub/Python_Programming-/genres_v2.csv"

sportify_Data = pd.read_csv(sportify_path)

sportify_Data.head()
sportify_Data.tail()

list(sportify_Data.columns)

plt.figure(figsize=(14,6))
sns.lineplot(data=sportify_Data)
# Out:
# /tmp/ipykernel_15834/1386391137.py:7: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   sportify_Data = pd.read_csv(sportify_path)
# /home/x38fed/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/x38fed/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/x38fed/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
