# %%
i = bytes.fromhex("335d366f5d6031767631707f")
print(i)
print(i.decode('latin1'))
# Out:
# b'3]6o]`1vv1p\x7f'
# 3]6o]`1vv1p

# %%
a = bytes.fromhex("335d366f5d6031767631707f")

for i in range(256):
    b = ""
    for j in a:
        b += chr(j ^ i)
    print(f"XOR {i}: {repr(b)}")
# Out:
# XOR 0: '3]6o]`1vv1p\x7f'
# XOR 1: '2\\7n\\a0ww0q~'
# XOR 2: '1_4m_b3tt3r}'
# XOR 3: '0^5l^c2uu2s|'
# XOR 4: '7Y2kYd5rr5t{'
# XOR 5: '6X3jXe4ss4uz'
# XOR 6: '5[0i[f7pp7vy'
# XOR 7: '4Z1hZg6qq6wx'
# XOR 8: ';U>gUh9~~9xw'
# XOR 9: ':T?fTi8\x7f\x7f8yv'
# XOR 10: '9W<eWj;||;zu'
# XOR 11: '8V=dVk:}}:{t'
# XOR 12: '?Q:cQl=zz=|s'
# XOR 13: '>P;bPm<{{<}r'
# XOR 14: '=S8aSn?xx?~q'
# XOR 15: '<R9`Ro>yy>\x7fp'
# XOR 16: '#M&\x7fMp!ff!`o'
# XOR 17: '"L\'~Lq gg an'
# XOR 18: '!O$}Or#dd#bm'
# XOR 19: ' N%|Ns"ee"cl'
# XOR 20: '\'I"{It%bb%dk'
# XOR 21: '&H#zHu$cc$ej'
# XOR 22: "%K yKv'``'fi"
# XOR 23: '$J!xJw&aa&gh'
# XOR 24: '+E.wEx)nn)hg'
# XOR 25: '*D/vDy(oo(if'
# XOR 26: ')G,uGz+ll+je'
# XOR 27: '(F-tF{*mm*kd'
# XOR 28: '/A*sA|-jj-lc'
# XOR 29: '.@+r@},kk,mb'
# XOR 30: '-C(qC~/hh/na'
# XOR 31: ',B)pB\x7f.ii.o`'
# XOR 32: '\x13}\x16O}@\x11VV\x11P_'
# XOR 33: '\x12|\x17N|A\x10WW\x10Q^'
# XOR 34: '\x11\x7f\x14M\x7fB\x13TT\x13R]'
# XOR 35: '\x10~\x15L~C\x12UU\x12S\\'
# ...
