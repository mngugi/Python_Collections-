# %% [markdown]
# # 📄 Convert a Word Document (.docx) to Markdown using `pypandoc`
#
# ***
#
# This script uses the `pypandoc` Python package to convert a Microsoft Word `.docx` file into Markdown format. It provides a quick way to turn structured documents into plaintext for use in Markdown-based environments like GitHub, Obsidian, or static site generators.
#
# ---
#
# ## 🛠️ Requirements
#
# Make sure you have the following installed:
#
# - Python
# - [`pypandoc`](https://pypi.org/project/pypandoc/)
# - [`pandoc`](https://pandoc.org/installing.html) (must be installed separately)
#
# ### 🔧 Installation
#
# ```bash
# pip install pypandoc
# # On Nix or Linux: install pandoc
# nix-shell -p pandoc  # or
# sudo apt install pandoc
#
# ```
# 💻 Python Script
#
# import pypandoc
#
# ### Convert a .docx file to Markdown
# output = pypandoc.convert_file(
#     'Literature Review Table.docx',  # Path to the input Word document
#     'markdown'                       # Target output format
# )
#
# ### Print the converted Markdown content
# print(output)
#
# ---
# ### 📥 Input
# Literature Review Table.docx: A Microsoft Word document containing tables, text, or formatted content you want to convert.
#
# ### 📤 Output
# The content of the .docx file as a Markdown-formatted string, printed to the console.
#
# ### ✅ Example Output
# Suppose the .docx contains a simple table:
#
# | Author | Year | Findings       |
# | ------ | ---- | -------------- |
# | Smith  | 2021 | Very promising |
#
# You can redirect this to a file if needed:
#
# ```python
#
# with open("output.md", "w") as f:
#     f.write(output)
# ```
#
# ### 🧠 Notes
# - pypandoc is a thin wrapper over Pandoc, which does the heavy lifting.
#
# - If you get errors, make sure Pandoc is available in your PATH.

# %%
import pypandoc

output = pypandoc.convert_file(
    'Literature Review Table.docx',
    'markdown'
)
print(output)
# Out:
# +-------------+-------------+-------------+-------------+-------------+
# | **Source**  | **Purpose/  | **Types of  | **Level of  | **Major     |
# |             | Thesis**    | Article/**  | Evidence**  | Findings**  |
# |             |             |             |             |             |
# |             |             | **Theory    |             |             |
# |             |             | /Research** |             |             |
# +-------------+-------------+-------------+-------------+-------------+
# | Authors and | What are    | What kind   | Where does  | Briefly     |
# | date of     | the authors | of          | this fall   | summarize   |
# |             |             | a           | on the LoE  | what the    |
# | item        | trying to   | rticle/text | table       | authors     |
# |             | do or       | is this     |             | found/acc   |
# |             | discover    |             |             | omplished/s |
# ...
