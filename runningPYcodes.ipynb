# %%
# %run appendlist.py
# Out:
#     _                               _   _     _     _
#    / \   _ __  _ __   ___ _ __   __| | | |   (_)___| |_
#   / _ \ | '_ \| '_ \ / _ \ '_ \ / _` | | |   | / __| __|
#  / ___ \| |_) | |_) |  __/ | | | (_| | | |___| \__ \ |_
# /_/   \_\ .__/| .__/ \___|_| |_|\__,_| |_____|_|___/\__|
#         |_|   |_|
#
# 1. Append an integer
# -------------------
# 2. Append a float
# -------------------
# 3. Append a double (float in Python)
# -------------------
# 4. Append a string
# -------------------
# -------------------
# [21, 50.0889, 2.0, 'Stingo', 'Stingo is a funny name!', ':0 , :))']
# -------------------

# %%
import pyfiglet

ascii_banner = pyfiglet.figlet_format("Hello, World!")
print(ascii_banner)
# Out:
#  _   _      _ _         __        __         _     _ _
# | | | | ___| | | ___    \ \      / /__  _ __| | __| | |
# | |_| |/ _ \ | |/ _ \    \ \ /\ / / _ \| '__| |/ _` | |
# |  _  |  __/ | | (_) |    \ V  V / (_) | |  | | (_| |_|
# |_| |_|\___|_|_|\___( )    \_/\_/ \___/|_|  |_|\__,_(_)
#                     |/

# %%
import sys
print(sys.executable)
# Out:
# /home/nova86/anaconda3/bin/python

# %%
# !{sys.executable} -m pip install pyfiglet
# Out:
# ...
#   Using cached pyfiglet-1.0.4-py3-none-any.whl.metadata (7.4 kB)
# Using cached pyfiglet-1.0.4-py3-none-any.whl (1.8 MB)
# ...

# %%
import pyfiglet
print(pyfiglet.figlet_format("Success!"))
# Out:
#  ____                              _
# / ___| _   _  ___ ___ ___  ___ ___| |
# \___ \| | | |/ __/ __/ _ \/ __/ __| |
#  ___) | |_| | (_| (_|  __/\__ \__ \_|
# |____/ \__,_|\___\___\___||___/___(_)

# %%
# %run sliceRecap.py
# Out:
# [1]

# %%
# %run t_test.py
# Out:
# 0.0 1.0
# -----------------------------------
# -1.8973665961010275 0.10753119493062718

# %%
# %run snippet1.py
# Out:
# low

# %%
# %run Acronyms.py
# Out:
#  ____        _   _
# |  _ \ _   _| |_| |__   ___  _ __
# | |_) | | | | __| '_ \ / _ \| '_ \
# |  __/| |_| | |_| | | | (_) | | | |
# |_|    \__, |\__|_| |_|\___/|_| |_|
#        |___/
#     _
#    / \   ___ _ __ ___  _ __  _   _ _ __ ___  ___
#   / _ \ / __| '__/ _ \| '_ \| | | | '_ ` _ \/ __|
#  / ___ \ (__| | | (_) | | | | |_| | | | | | \__ \
# /_/   \_\___|_|  \___/|_| |_|\__, |_| |_| |_|___/
#                              |___/
#
# Python Acronyms and Their Meanings:
#
# PEP: Python Enhancement Proposal
# PEP: Python Enhancement Proposal
# GIL: Global Interpreter Lock
# GIL: Global Interpreter Lock
# CPython: C implementation of Python
# CPython: C implementation of Python
# IDLE: Integrated Development and Learning Environment
# IDLE: Integrated Development and Learning Environment
# PyPI: Python Package Index
# PyPI: Python Package Index
# Pandas: Panel Data
# Pandas: Panel Data
# SciPy: Scientific Python
# SciPy: Scientific Python
# ...

# %%
# %run spell_checking.py

# %%
# %run spellCheck.py

# %%
from art import text2art

print_out = text2art("Use Art")
print(print_out)
# Out:
#  _   _                 _           _
# | | | | ___   ___     / \    _ __ | |_
# | | | |/ __| / _ \   / _ \  | '__|| __|
# | |_| |\__ \|  __/  / ___ \ | |   | |_
#  \___/ |___/ \___| /_/   \_\|_|    \__|

# %%
# %run maps.py
# Out:
# [4, 5, 6, 1, 8]
# Double the new list of number by  2:
# [8, 10, 12, 2, 16]
# [6, 15, 27]
# [8, 20, 36]
# [5, 10, 15]
# [['hi', 'bye', 'hi', 'bye'], 'hello hello ', 'Globa Warming! Globa Warming! ', [9, 2, 9, 2], 8]
# ['USA', 'ESP', 'CHN', 'JPN', 'MEX', 'CAN', 'RUS', 'RSA', 'JAM']

# %%
# %run socket1.py
# Out:
# b''
