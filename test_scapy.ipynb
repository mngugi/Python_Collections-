# %%
from scapy.all import *
import warnings

warnings.filterwarnings('ignore')

pkt = IP()

pkt.canvas_dump()

print('---------------------------------------')
print('')


packets = rdpcap('sample.pcap')
packets.summary()  

ans, unans = traceroute('www.secdev.org', maxttl=15)
pkt.canvas_dump()
ans.world_trace()
# Out:
# ---------------------------------------
#
# Ether / IP / TCP 192.168.100.9:54894 > 34.107.221.82:http A
# Ether / IP / TCP 192.168.100.9:54882 > 34.107.221.82:http A
# Ether / IP / TCP 34.107.221.82:http > 192.168.100.9:54882 A
# Ether / IP / TCP 34.107.221.82:http > 192.168.100.9:54894 A
# Ether / IP / TCP 192.168.100.9:48916 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:48900 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:56760 > 172.217.170.163:http A
# Ether / IP / TCP 192.168.100.9:48892 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:56748 > 172.217.170.163:http A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56760 A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56748 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48916 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48892 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48900 A
# Ether / IP / TCP 192.168.100.9:56776 > 172.217.170.163:http A
# Ether / IP / TCP 192.168.100.9:safetynetp > 192.229.221.95:http A
# Ether / IP / TCP 192.168.100.9:40306 > 41.206.100.35:http A
# Ether / IP / TCP 192.168.100.9:40290 > 41.206.100.35:http A
# Ether / IP / TCP 192.168.100.9:39988 > 192.229.221.95:http A
# Ether / IP / TCP 41.206.100.35:http > 192.168.100.9:40306 A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56776 A
# Ether / IP / TCP 192.229.221.95:http > 192.168.100.9:safetynetp A
# Ether / IP / TCP 41.206.100.35:http > 192.168.100.9:40290 A
# Ether / IP / TCP 192.229.221.95:http > 192.168.100.9:39988 A
# Ether / IP / TCP 192.168.100.9:40022 > 35.190.72.216:https PA / Raw
# Ether / IP / TCP 192.168.100.9:40022 > 35.190.72.216:https FA
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:40022 A
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:40022 FA
# Ether / IP / TCP 192.168.100.9:40022 > 35.190.72.216:https A
# Ether / IP / UDP 192.168.100.1:56299 > 239.255.255.250:ssdp / Raw
# Ether / IP / UDP 192.168.100.1:56299 > 239.255.255.250:ssdp / Raw
# Ether / IP / UDP 192.168.100.1:56299 > 239.255.255.250:ssdp / Raw
# Ether / IP / UDP 192.168.100.1:56299 > 239.255.255.250:ssdp / Raw
# Ether / IP / TCP 192.168.100.9:49874 > 104.244.42.65:https A
# Ether / IP / TCP 104.244.42.65:https > 192.168.100.9:49874 A
# Ether / IP / TCP 192.168.100.9:54882 > 34.107.221.82:http A
# Ether / IP / TCP 192.168.100.9:54894 > 34.107.221.82:http A
# Ether / IP / TCP 34.107.221.82:http > 192.168.100.9:54882 A
# Ether / IP / TCP 34.107.221.82:http > 192.168.100.9:54894 A
# Ether / IP / UDP 192.168.100.9:47408 > 239.255.255.250:ssdp / Raw
# Ether / IP / UDP 192.168.100.5:ssdp > 192.168.100.9:47408 / Raw
# Ether / IP / UDP 192.168.100.9:47408 > 239.255.255.250:ssdp / Raw
# Ether / IP / UDP 192.168.100.5:ssdp > 192.168.100.9:47408 / Raw
# Ether / IP / TCP 192.168.100.9:48900 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:48892 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:48916 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:56760 > 172.217.170.163:http A
# Ether / IP / TCP 192.168.100.9:56748 > 172.217.170.163:http A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56748 A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56760 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48916 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48892 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48900 A
# Ether / IP / TCP 192.168.100.9:39988 > 192.229.221.95:http A
# Ether / IP / TCP 192.168.100.9:40306 > 41.206.100.35:http A
# Ether / IP / TCP 192.168.100.9:40290 > 41.206.100.35:http A
# Ether / IP / TCP 192.168.100.9:56776 > 172.217.170.163:http A
# Ether / IP / TCP 192.168.100.9:safetynetp > 192.229.221.95:http A
# Ether / IP / TCP 41.206.100.35:http > 192.168.100.9:40306 A
# Ether / IP / TCP 41.206.100.35:http > 192.168.100.9:40290 A
# Ether / IP / TCP 192.229.221.95:http > 192.168.100.9:39988 A
# Ether / IP / TCP 192.229.221.95:http > 192.168.100.9:safetynetp A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56776 A
# Ether / IP / UDP 192.168.100.9:47408 > 239.255.255.250:ssdp / Raw
# Ether / IP / UDP 192.168.100.5:ssdp > 192.168.100.9:47408 / Raw
# Ether / IP / UDP 192.168.100.9:47408 > 239.255.255.250:ssdp / Raw
# Ether / IP / UDP 192.168.100.5:ssdp > 192.168.100.9:47408 / Raw
# Ether / ARP who has 192.168.100.9 says 192.168.100.5
# Ether / ARP is at 96:43:2d:a5:9e:d5 says 192.168.100.9
# Ether / IP / UDP 192.168.100.9:38267 > 172.67.202.44:https / Raw
# Ether / IP / UDP 192.168.100.9:38267 > 172.67.202.44:https / Raw
# Ether / IP / UDP 192.168.100.9:38267 > 172.67.202.44:https / Raw
# Ether / IP / UDP 192.168.100.9:38267 > 172.67.202.44:https / Raw
# Ether / IP / UDP / DNS Qry "b'www.youtube.com.'"
# Ether / IP / UDP / DNS Qry "b'www.youtube.com.'"
# Ether / IP / UDP / DNS Ans "172.217.170.174"
# Ether / IP / UDP 192.168.100.9:38267 > 172.67.202.44:https / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 192.168.100.9:38267 > 172.67.202.44:https / Raw
# Ether / IP / UDP / DNS Ans "b'youtube-ui.l.google.com.'"
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 192.168.100.9:38267 > 172.67.202.44:https / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 192.168.100.9:38267 > 172.67.202.44:https / Raw
# Ether / IP / UDP 192.168.100.9:38267 > 172.67.202.44:https / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 192.168.100.9:38267 > 172.67.202.44:https / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 172.67.202.44:https > 192.168.100.9:38267 / Raw
# Ether / IP / UDP 192.168.100.9:38267 > 172.67.202.44:https / Raw
# Ether / IP / UDP 192.168.100.9:47532 > 216.58.223.78:https / Raw
# Ether / IP / UDP 216.58.223.78:https > 192.168.100.9:47532 / Raw
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https S
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:50520 SA
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https A
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https PA / Raw
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:50520 A
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:50520 PA / Raw
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https A
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https PA / Raw
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https PA / Raw
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https PA / Raw
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https PA / Raw
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https PA / Raw
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:50520 A
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:50520 A
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:50520 PA / Raw
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https PA / Raw
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:50520 A
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:50520 PA / Raw
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:50520 A
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https A
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:50520 PA / Raw
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https A
# Ether / IP / TCP 192.168.100.9:50520 > 35.190.72.216:https PA / Raw
# Ether / IP / TCP 35.190.72.216:https > 192.168.100.9:50520 A
# Ether / IP / TCP 192.168.100.9:54894 > 34.107.221.82:http A
# Ether / IP / TCP 192.168.100.9:54882 > 34.107.221.82:http A
# Ether / IP / TCP 34.107.221.82:http > 192.168.100.9:54882 A
# Ether / IP / TCP 34.107.221.82:http > 192.168.100.9:54894 A
# Ether / IP / TCP 192.168.100.9:48916 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:56760 > 172.217.170.163:http A
# Ether / IP / TCP 192.168.100.9:56748 > 172.217.170.163:http A
# Ether / IP / TCP 192.168.100.9:48900 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:48892 > 2.19.251.56:http A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56748 A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56760 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48916 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48892 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48900 A
# Ether / IP / TCP 192.168.100.9:39988 > 192.229.221.95:http A
# Ether / IP / TCP 192.168.100.9:56776 > 172.217.170.163:http A
# Ether / IP / TCP 192.168.100.9:40306 > 41.206.100.35:http A
# Ether / IP / TCP 192.168.100.9:safetynetp > 192.229.221.95:http A
# Ether / IP / TCP 192.168.100.9:40290 > 41.206.100.35:http A
# Ether / IP / TCP 192.229.221.95:http > 192.168.100.9:39988 A
# Ether / IP / TCP 41.206.100.35:http > 192.168.100.9:40306 A
# Ether / IP / TCP 41.206.100.35:http > 192.168.100.9:40290 A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56776 A
# Ether / IP / TCP 192.229.221.95:http > 192.168.100.9:safetynetp A
# Ether / IP / UDP / DNS Qry "b'api.x.com.'"
# Ether / IP / UDP / DNS Qry "b'api.x.com.'"
# Ether / IP / TCP 192.168.100.9:49874 > 104.244.42.65:https PA / Raw
# Ether / IP / TCP 192.168.100.9:49874 > 104.244.42.65:https PA / Raw
# Ether / IP / UDP / DNS Ans "b'tpop-api.x.com.'"
# Ether / IP / UDP / DNS Ans "b'tpop-api.x.com.'"
# Ether / IP / TCP 192.168.100.9:43366 > 104.244.42.66:https S
# Ether / IP / TCP 104.244.42.65:https > 192.168.100.9:49874 A
# Ether / IP / TCP 104.244.42.65:https > 192.168.100.9:49874 PA / Raw
# Ether / IP / TCP 192.168.100.9:49874 > 104.244.42.65:https A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43366 SA
# Ether / IP / TCP 192.168.100.9:43366 > 104.244.42.66:https A
# Ether / IP / TCP 192.168.100.9:43366 > 104.244.42.66:https A / Raw
# Ether / IP / TCP 192.168.100.9:43366 > 104.244.42.66:https PA / Raw
# Ether / IP / TCP 104.244.42.65:https > 192.168.100.9:49874 PA / Raw
# Ether / IP / TCP 192.168.100.9:49874 > 104.244.42.65:https A
# Ether / IP / TCP 192.168.100.9:49874 > 104.244.42.65:https PA / Raw
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43366 A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43366 PA / Raw
# Ether / IP / TCP 192.168.100.9:43366 > 104.244.42.66:https A
# Ether / IP / TCP 192.168.100.9:43366 > 104.244.42.66:https PA / Raw
# Ether / IP / TCP 192.168.100.9:43366 > 104.244.42.66:https PA / Raw
# Ether / IP / TCP 192.168.100.9:43366 > 104.244.42.66:https PA / Raw
# Ether / IP / TCP 104.244.42.65:https > 192.168.100.9:49874 A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43366 A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43366 PA / Raw
# Ether / IP / TCP 192.168.100.9:43366 > 104.244.42.66:https PA / Raw
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43366 PA / Raw
# Ether / IP / TCP 192.168.100.9:43382 > 104.244.42.66:https S
# Ether / IP / TCP 192.168.100.9:43366 > 104.244.42.66:https A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43382 SA
# Ether / IP / TCP 192.168.100.9:43382 > 104.244.42.66:https A
# Ether / IP / TCP 192.168.100.9:43382 > 104.244.42.66:https A / Raw
# Ether / IP / TCP 192.168.100.9:43382 > 104.244.42.66:https PA / Raw
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43366 A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43382 A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43382 A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43382 PA / Raw
# Ether / IP / TCP 192.168.100.9:43382 > 104.244.42.66:https A
# Ether / IP / TCP 192.168.100.9:43382 > 104.244.42.66:https PA / Raw
# Ether / IP / TCP 192.168.100.9:43382 > 104.244.42.66:https PA / Raw
# Ether / IP / TCP 192.168.100.9:43382 > 104.244.42.66:https PA / Raw
# Ether / IP / TCP 192.168.100.9:55374 > 151.101.193.32:https A
# Ether / IP / TCP 151.101.193.32:https > 192.168.100.9:55374 A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43382 A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43382 PA / Raw
# Ether / IP / TCP 192.168.100.9:43382 > 104.244.42.66:https PA / Raw
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43382 A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43382 PA / Raw
# Ether / IP / TCP 192.168.100.9:43382 > 104.244.42.66:https A
# Ether / IP / TCP 104.244.42.66:https > 192.168.100.9:43382 A
# Ether / IP / TCP 192.168.100.9:54894 > 34.107.221.82:http A
# Ether / IP / TCP 192.168.100.9:54882 > 34.107.221.82:http A
# Ether / IP / TCP 34.107.221.82:http > 192.168.100.9:54894 A
# Ether / IP / TCP 34.107.221.82:http > 192.168.100.9:54882 A
# Ether / IP / TCP 192.168.100.9:48900 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:48916 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:48892 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:56760 > 172.217.170.163:http A
# Ether / IP / TCP 192.168.100.9:56748 > 172.217.170.163:http A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56748 A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56760 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48916 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48892 A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48900 A
# Ether / IP / TCP 192.168.100.9:39988 > 192.229.221.95:http A
# Ether / IP / TCP 192.168.100.9:40306 > 41.206.100.35:http A
# Ether / IP / TCP 192.168.100.9:56776 > 172.217.170.163:http A
# Ether / IP / TCP 192.168.100.9:40290 > 41.206.100.35:http A
# Ether / IP / TCP 192.168.100.9:safetynetp > 192.229.221.95:http A
# Ether / IP / TCP 41.206.100.35:http > 192.168.100.9:40306 A
# Ether / IP / TCP 41.206.100.35:http > 192.168.100.9:40290 A
# Ether / IP / TCP 192.229.221.95:http > 192.168.100.9:39988 A
# Ether / IP / TCP 192.229.221.95:http > 192.168.100.9:safetynetp A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56776 A
# Ether / IP / TCP 192.168.100.9:40290 > 41.206.100.35:http FA
# Ether / IP / TCP 192.168.100.9:39988 > 192.229.221.95:http FA
# Ether / IP / TCP 192.168.100.9:safetynetp > 192.229.221.95:http FA
# Ether / IP / TCP 192.168.100.9:56776 > 172.217.170.163:http FA
# Ether / IP / TCP 192.168.100.9:40306 > 41.206.100.35:http FA
# Ether / IP / TCP 192.168.100.9:56748 > 172.217.170.163:http FA
# Ether / IP / TCP 192.168.100.9:48916 > 2.19.251.56:http FA
# Ether / IP / TCP 192.168.100.9:48892 > 2.19.251.56:http FA
# Ether / IP / TCP 192.168.100.9:48900 > 2.19.251.56:http FA
# Ether / IP / TCP 192.168.100.9:56760 > 172.217.170.163:http FA
# Ether / IP / TCP 192.229.221.95:http > 192.168.100.9:39988 FA
# Ether / IP / TCP 192.168.100.9:39988 > 192.229.221.95:http A
# Ether / IP / TCP 192.229.221.95:http > 192.168.100.9:safetynetp FA
# Ether / IP / TCP 192.168.100.9:safetynetp > 192.229.221.95:http A
# Ether / IP / TCP 41.206.100.35:http > 192.168.100.9:40306 FA
# Ether / IP / TCP 192.168.100.9:40306 > 41.206.100.35:http A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56776 FA
# Ether / IP / TCP 192.168.100.9:56776 > 172.217.170.163:http A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56748 FA
# Ether / IP / TCP 192.168.100.9:56748 > 172.217.170.163:http A
# Ether / IP / TCP 172.217.170.163:http > 192.168.100.9:56760 FA
# Ether / IP / TCP 192.168.100.9:56760 > 172.217.170.163:http A
# Ether / IP / TCP 41.206.100.35:http > 192.168.100.9:40290 FA
# Ether / IP / TCP 192.168.100.9:40290 > 41.206.100.35:http A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48916 FA
# Ether / IP / TCP 192.168.100.9:48916 > 2.19.251.56:http A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48892 FA
# Ether / IP / TCP 192.168.100.9:48892 > 2.19.251.56:http A
# Ether / IP / TCP 2.19.251.56:http > 192.168.100.9:48900 FA
# Ether / IP / TCP 192.168.100.9:48900 > 2.19.251.56:http A
# Ether / IP / TCP 192.168.100.9:59276 > 34.107.243.93:https PA / Raw
# Ether / IP / TCP 192.168.100.9:59068 > 34.117.188.166:https PA / Raw
# Ether / IP / TCP 192.168.100.9:59776 > 34.117.121.53:https PA / Raw
# Ether / IP / TCP 192.168.100.9:59064 > 34.117.188.166:https PA / Raw
# Ether / IP / TCP 192.168.100.9:55266 > 34.160.144.191:https PA / Raw
# Ether / IP / TCP 34.107.243.93:https > 192.168.100.9:59276 PA / Raw
# Ether / IP / TCP 192.168.100.9:59276 > 34.107.243.93:https A
# Ether / IP / TCP 34.117.121.53:https > 192.168.100.9:59776 PA / Raw
# Ether / IP / TCP 192.168.100.9:59776 > 34.117.121.53:https A
# Ether / IP / TCP 34.117.188.166:https > 192.168.100.9:59068 PA / Raw
# Ether / IP / TCP 192.168.100.9:59068 > 34.117.188.166:https A
# Ether / IP / TCP 34.117.188.166:https > 192.168.100.9:59064 PA / Raw
# Ether / IP / TCP 192.168.100.9:59064 > 34.117.188.166:https A
# Ether / IP / TCP 34.160.144.191:https > 192.168.100.9:55266 PA / Raw
# Ether / IP / TCP 192.168.100.9:55266 > 34.160.144.191:https A
# Ether / IP / TCP 192.168.100.9:49212 > 34.149.100.209:https PA / Raw
# Ether / IP / TCP 34.149.100.209:https > 192.168.100.9:49212 PA / Raw
# Ether / IP / TCP 192.168.100.9:49212 > 34.149.100.209:https A
# Ether / IP / TCP 192.168.100.9:44608 > 34.120.208.123:https PA / Raw
# Ether / IP / TCP 34.120.208.123:https > 192.168.100.9:44608 PA / Raw
# Ether / IP / TCP 192.168.100.9:44608 > 34.120.208.123:https A
# Ether / IP / TCP 192.168.100.9:54894 > 34.107.221.82:http A
# Ether / IP / TCP 192.168.100.9:54882 > 34.107.221.82:http A
# Ether / IP / TCP 34.107.221.82:http > 192.168.100.9:54882 A
# Ether / IP / TCP 34.107.221.82:http > 192.168.100.9:54894 A
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 17
#      14 packets = rdpcap('sample.pcap')
#      15 packets.summary()
# ---> 17 ans, unans = traceroute('www.secdev.org', maxttl=15)
#      18 pkt.canvas_dump()
#      19 ans.world_trace()
#
# File ~/.local/lib/python3.12/site-packages/scapy/layers/inet.py:1851, in traceroute(target, dport, minttl, maxttl, sport, l4, filter, timeout, verbose, **kargs)
#    1849     filter = "(icmp and (icmp[0]=3 or icmp[0]=4 or icmp[0]=5 or icmp[0]=11 or icmp[0]=12)) or (tcp and (tcp[13] & 0x16 > 0x10))"  # noqa: E501
#    1850 if l4 is None:
# -> 1851     a, b = sr(IP(dst=target, id=RandShort(), ttl=(minttl, maxttl)) / TCP(seq=RandInt(), sport=sport, dport=dport),  # noqa: E501
#    1852               timeout=timeout, filter=filter, verbose=verbose, **kargs)
#    1853 else:
#    1854     # this should always work
#    1855     filter = "ip"
#
# File ~/.local/lib/python3.12/site-packages/scapy/sendrecv.py:650, in sr(x, promisc, filter, iface, nofilter, *args, **kargs)
#     646 """
#     647 Send and receive packets at layer 3
#     648 """
#     649 iface = _interface_selection(iface, x)
# --> 650 s = conf.L3socket(promisc=promisc, filter=filter,
#     651                   iface=iface, nofilter=nofilter)
#     652 result = sndrcv(s, x, *args, **kargs)
#     653 s.close()
#
# File ~/.local/lib/python3.12/site-packages/scapy/arch/linux.py:484, in L2Socket.__init__(self, iface, type, promisc, filter, nofilter, monitor)
#     482 self.type = type
#     483 self.promisc = conf.sniff_promisc if promisc is None else promisc
# --> 484 self.ins = socket.socket(
#     485     socket.AF_PACKET, socket.SOCK_RAW, socket.htons(type))
#     486 self.ins.setsockopt(socket.SOL_SOCKET, socket.SO_RCVBUF, 0)
#     487 if not nofilter:
#
# File /usr/lib64/python3.12/socket.py:233, in socket.__init__(self, family, type, proto, fileno)
#     231     if proto == -1:
#     232         proto = 0
# --> 233 _socket.socket.__init__(self, family, type, proto, fileno)
#     234 self._io_refs = 0
#     235 self._closed = False
#
# PermissionError: [Errno 1] Operation not permitted

# %%
# !pip3 install PyX
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: PyX in /home/vector64/.local/lib/python3.12/site-packages (0.16)

# %%
# !pip3 install --user PyX
# Out:
# Requirement already satisfied: PyX in /home/vector64/.local/lib/python3.12/site-packages (0.16)
